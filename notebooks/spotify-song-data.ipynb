# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

plt.close("all")

df = pd.read_csv('../data/spotify_data_clean.csv')

x = pd.to_numeric(df['track_number'], errors='coerce')
y = pd.to_numeric(df['track_duration_min'], errors='coerce')

plt.scatter(x,y)
plt.xlabel("Track number")
plt.title("Track number vs track duration")
plt.ylabel("Track duration, in minutes")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 import scipy.stats as st
#       6 plt.close("all")
# ----> 8 df = pd.read_csv('../data/spotify_data_clean.csv')
#      10 x = pd.to_numeric(df['track_number'], errors='coerce')
#      11 y = pd.to_numeric(df['track_duration_min'], errors='coerce')
#
# ...

# %%
print('Track number: mean=%.3f stdv=%.3f' % (np.mean(x), np.std(x)))
print('Track duration: mean=%.3f stdv=%.3f' % (np.mean(y), np.std(y)))


df.head(10)
df.info()
df.describe()


# print(st.pearsonr(x,y))
# Out:
# Track number: mean=5.975 stdv=7.056
# Track duration: mean=3.494 stdv=1.058
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8581 entries, 0 to 8580
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8581 non-null   object
#  1   track_name          8581 non-null   object
#  2   track_number        8581 non-null   object
#  3   track_popularity    8581 non-null   object
#  4   explicit            8570 non-null   object
#  5   artist_name         8578 non-null   object
#  6   artist_popularity   8581 non-null   object
#  7   artist_followers    8581 non-null   object
#  8   artist_genres       5230 non-null   object
#  9   album_id            8580 non-null   object
#  10  album_name          8580 non-null   object
#  11  album_release_date  8554 non-null   object
#  12  album_total_tracks  8554 non-null   float64
#  13  album_type          8552 non-null   object
# ...
